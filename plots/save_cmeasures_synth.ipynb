# %%
import os
from glob import glob
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import torch
import torch.nn as nn
from numpy.core.defchararray import find
from pandas.api.types import CategoricalDtype
from scipy import stats
from sklearn import linear_model, preprocessing
from sklearn.metrics import (RocCurveDisplay, auc, confusion_matrix,
                             mean_squared_error, roc_curve)
from sklearn.model_selection import KFold, RandomizedSearchCV, train_test_split
from sklearn.svm import SVC
from sklearn.utils.fixes import loguniform
from torch.utils.data import DataLoader, TensorDataset

from label_flip_revised.simple_nn_model import SimpleModel
from label_flip_revised.torch_utils import evaluate, train_model
from label_flip_revised.utils import create_dir, open_csv

# %%
PATH_ROOT = Path(os.getcwd()).absolute().parent
print(PATH_ROOT)
# Out:
# /home/lukec/workspace/label_flip_revised

# %%
path_cm = sorted(glob(os.path.join(PATH_ROOT, 'results', 'synth_nn', '*.csv')))
print(len(path_cm))
print(path_cm[:5])
# Out:
# 54
# ['/home/lukec/workspace/label_flip_revised/results/synth_nn/synth_nn_poison_0.csv', '/home/lukec/workspace/label_flip_revised/results/synth_nn/synth_nn_poison_1.csv', '/home/lukec/workspace/label_flip_revised/results/synth_nn/synth_nn_poison_10.csv', '/home/lukec/workspace/label_flip_revised/results/synth_nn/synth_nn_poison_11.csv', '/home/lukec/workspace/label_flip_revised/results/synth_nn/synth_nn_poison_12.csv']

# %%
df_cm = pd.DataFrame()
for p in path_cm:
    _df = pd.read_csv(p)
    df_cm = pd.concat([df_cm, _df], ignore_index=True)

# %%
# Add rates
rates = [float(Path(d).stem.split('_')[-1]) for d in df_cm['Data'].to_list()]
df_cm['Rate'] = rates
df_cm = df_cm[df_cm['Rate'] <= 0.41]
print(df_cm.shape)
# Out:
# (2397, 37)

# %%
# Add filepath
df_cm['Filepath'] = df_cm['Data'].apply(lambda x: os.path.join('data', 'synth', 'alfa_nn', x))
df_cm['Data'] = df_cm['Data'].apply(lambda x: x[:-len('_nn_ALFA_0.05.csv')])

# %%
path_clean = sorted(glob(os.path.join(PATH_ROOT, 'results', 'synth_svm', '*clean*')))
df_cm_clean = pd.DataFrame()
for p in path_clean:
    _df = pd.read_csv(p)
    df_cm_clean = pd.concat([df_cm_clean, _df], ignore_index=True)

df_cm_clean['Rate'] = 0
df_cm_clean['Filepath'] = df_cm_clean['Data'].apply(lambda x: os.path.join('data', 'synth', 'train', '{}_clean_train.csv'.format(x.split('.')[0])))
df_cm_clean['Data'] = df_cm_clean['Data'].apply(lambda x: x.split('.')[0])

df_cm = pd.concat([df_cm_clean, df_cm], ignore_index=True)

# %%
# Remove NA
print('# of columns before removing NA:', len(df_cm.columns) - 1)  # Name does not count
cols_not_na = df_cm.columns[df_cm.notna().any()].tolist()
df_cm = df_cm[cols_not_na]
print('# of columns after removing NA:', len(df_cm.columns) - 1)  # Name does not count
print(cols_not_na)
# Out:
# # of columns before removing NA: 37
# # of columns after removing NA: 30
# ['Data', 'overlapping.F1.mean', 'overlapping.F1.sd', 'overlapping.F1v.mean', 'overlapping.F2.mean', 'overlapping.F3.mean', 'overlapping.F4.mean', 'neighborhood.N1', 'neighborhood.N2.mean', 'neighborhood.N2.sd', 'neighborhood.N3.mean', 'neighborhood.N3.sd', 'neighborhood.N4.mean', 'neighborhood.N4.sd', 'neighborhood.T1.mean', 'neighborhood.T1.sd', 'neighborhood.LSC', 'linearity.L1.mean', 'linearity.L2.mean', 'linearity.L3.mean', 'dimensionality.T2', 'dimensionality.T3', 'dimensionality.T4', 'balance.C1', 'balance.C2', 'network.Density', 'network.ClsCoef', 'network.Hubs.mean', 'network.Hubs.sd', 'Rate', 'Filepath']

# %%
df_cm = df_cm.sort_values(by=['Data', 'Rate'], ignore_index=True)
df_cm['Testpath'] = df_cm['Data'].apply(lambda x: os.path.join('data', 'synth', 'test', f'{x}_clean_test.csv'))

# %%
df_cm['Train'] = 0.
df_cm['Test'] = 0.

# %%
COL_NAMES = ['Data', 'F1', 'F1 SD', 'F1v', 'F2', 'F3', 'F4', 'N1', 
    'N2', 'N2 SD', 'N3 ', 'N3 SD', 'N4', 'N4 SD', 'T1', 'T1 SD', 'LSC', 
    'L1', 'L2', 'L3', 'T2', 'T3', 'T4', 'C1', 'C2', 'Density', 'ClsCoef', 
    'Hubs', 'HubsSD', 'Rate', 'Filepath', 'Testpath', 'Train', 'Test']
new_names_map = {df_cm.columns[i]:COL_NAMES[i] for i in range(len(COL_NAMES))}
df_cm = df_cm.rename(new_names_map, axis=1)

# %%
# Load clean score
def update_score(df_score, rate, df_cm):
    for i in range(df_score.shape[0]):
        data = df_score.loc[i, 'data']
        train = df_score.loc[i, 'train']
        test = df_score.loc[i, 'test']
        idx = df_cm[(df_cm['Data'] == data) & (df_cm['Rate'] == rate)].index
        df_cm.loc[idx, 'Train'] = train
        df_cm.loc[idx, 'Test'] = test

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
    print('Running on CPU!')

HIDDEN_LAYER = 128
LR = 0.001  # Learning rate.
MAX_EPOCHS = 400  # Number of iteration for training.
BATCH_SIZE = 128

# %%
def get_dataloader(X, y, batch_size=BATCH_SIZE, shuffle=True):
    dataset = TensorDataset(torch.from_numpy(X).type(torch.float32),
                                  torch.from_numpy(y).type(torch.int64))
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=shuffle)
    return dataloader

# %%
# Load clean score
df_score_clean = pd.read_csv(os.path.join(PATH_ROOT, 'results', 'synth_clean_score.csv'))
update_score(df_score_clean, 0, df_cm)

# %%
path_output = os.path.join(PATH_ROOT, 'results')
path_model = os.path.join(path_output, 'torch')
create_dir(path_model)

# %%
df_cm.head()
# Out:
#                    Data        F1     F1 SD       F1v        F2     F3  \
# 0  f04_i02_r00_c01_w6_1  0.810730  0.372452  0.054200  0.334868  0.504
# 1  f04_i02_r00_c01_w6_1  0.871642  0.236221  0.157394  0.478438  0.762
# 2  f04_i02_r00_c01_w6_1  0.898315  0.188025  0.250773  0.565290  0.690
# 3  f04_i02_r00_c01_w6_1  0.924654  0.092116  0.302377  0.436307  0.690
# 4  f04_i02_r00_c01_w6_1  0.932818  0.088960  0.343645  0.512272  0.631
#
#        F4     N1        N2     N2 SD  ...        C2   Density   ClsCoef  \
# 0  0.4245  0.030  0.200008  0.109163  ...  0.077664  0.848518  0.406686
# 1  0.6860  0.082  0.262551  0.115698  ...  0.020594  0.862773  0.400181
# 2  0.6360  0.126  0.264643  0.140696  ...  0.278243  0.865011  0.415929
# 3  0.6140  0.115  0.279178  0.123644  ...  0.019025  0.870060  0.382698
# 4  0.5850  0.107  0.261546  0.134748  ...  0.532007  0.863499  0.437701
#
#        Hubs    HubsSD  Rate  \
# 0  0.766283  0.302880  0.00
# 1  0.770124  0.299065  0.05
# 2  0.642544  0.312808  0.10
# 3  0.761814  0.292958  0.15
# 4  0.639688  0.248479  0.20
#
#                                             Filepath  \
# 0  data/synth/alfa_nn/f04_i02_r00_c01_w6_1_clean_...
# 1  data/synth/alfa_nn/f04_i02_r00_c01_w6_1_nn_ALF...
# 2  data/synth/alfa_nn/f04_i02_r00_c01_w6_1_nn_ALF...
# 3  data/synth/alfa_nn/f04_i02_r00_c01_w6_1_nn_ALF...
# 4  data/synth/alfa_nn/f04_i02_r00_c01_w6_1_nn_ALF...
#
#                                             Testpath  Train   Test
# 0  data/synth/test/f04_i02_r00_c01_w6_1_clean_tes...  0.985  0.994
# 1  data/synth/test/f04_i02_r00_c01_w6_1_clean_tes...  0.000  0.000
# 2  data/synth/test/f04_i02_r00_c01_w6_1_clean_tes...  0.000  0.000
# 3  data/synth/test/f04_i02_r00_c01_w6_1_clean_tes...  0.000  0.000
# 4  data/synth/test/f04_i02_r00_c01_w6_1_clean_tes...  0.000  0.000
#
# [5 rows x 34 columns]

# %%
RATES = [f'{r:.2f}' for r in np.arange(0.05, 0.41, 0.05)]
print(RATES)
postfix_torch = '_SimpleNN.torch'

for rate in RATES:
    print(f'Current poison rate: {rate}...')
    path_score = os.path.join(PATH_ROOT, 'results', f'synth_falfa_{rate}_score.csv')
    if os.path.exists(path_score):
        df_score = pd.read_csv(path_score)
        update_score(df_score, rate, df_cm)
    else:
        acc_train = []
        acc_test = []
        datanames = []

        for i in df_cm[df_cm['Rate'] == float(rate)].index:
            dataname = df_cm.iloc[i]['Data']
            datanames.append(dataname)

            path_train = os.path.join(PATH_ROOT, df_cm.iloc[i]['Filepath'])
            path_test = os.path.join(PATH_ROOT, df_cm.iloc[i]['Testpath'])

            X_po, y_po, _ = open_csv(path_train)
            X_test, y_test, _ = open_csv(path_test)
            n_features = X_po.shape[1]

            dataloader_poison = get_dataloader(X_po, y_po, shuffle=True)
            dataloader_test = get_dataloader(X_test, y_test, shuffle=False)

            model = SimpleModel(n_features, hidden_dim=HIDDEN_LAYER, output_dim=2).to(device)
            optimizer = torch.optim.SGD(model.parameters(), lr=LR, momentum=0.8)
            loss_fn = nn.CrossEntropyLoss()

            dataname_poison = '{}_nn_ALFA_{}{}'.format(dataname, rate, postfix_torch)
            _path_model = os.path.join(path_model, dataname_poison)
            if os.path.exists(_path_model):
                model.load_state_dict(torch.load(_path_model, map_location=device))
            else:
                train_model(model, dataloader_poison, optimizer, loss_fn, device, MAX_EPOCHS)
                torch.save(model.state_dict(), _path_model)

            acc_po, _ = evaluate(dataloader_poison, model, loss_fn, device)
            acc_te, _ = evaluate(dataloader_test, model, loss_fn, device)
            acc_train.append(acc_po)
            acc_test.append(acc_te)

            if i % 10 == 0:
                print(f'[{dataname}] Acc train: {acc_po*100:.2f} test: {acc_te*100:.2f}')
        results = {
            'data': datanames,
            'train': acc_train,
            'test': acc_test,
        }
        df_score = pd.DataFrame(results)
        df_score.to_csv(os.path.join(path_output, f'synth_falfa_{rate}_score.csv'), index=False)
        update_score(df_score, float(rate), df_cm)
# Out:
# ['0.05', '0.10', '0.15', '0.20', '0.25', '0.30', '0.35', '0.40']
# Current poison rate: 0.05...
# [f04_i02_r01_c01_w5_1] Acc train: 93.10 test: 98.80
# [f07_i04_r00_c03_w4_1] Acc train: 80.50 test: 83.40
# [f08_i07_r00_c01_w5_1] Acc train: 88.90 test: 93.70
# [f10_i05_r00_c02_w4_1] Acc train: 80.80 test: 84.30
# [f10_i09_r00_c03_w6_1] Acc train: 80.80 test: 72.90
# [f12_i08_r02_c03_w5_1] Acc train: 74.70 test: 79.10
# [f13_i07_r03_c03_w6_1] Acc train: 75.20 test: 78.20
# [f14_i08_r05_c07_w4_1] Acc train: 71.30 test: 64.50
# [f15_i08_r04_c03_w6_1] Acc train: 82.60 test: 79.40
# [f15_i15_r00_c08_w6_1] Acc train: 76.20 test: 65.50
# [f17_i09_r02_c03_w5_1] Acc train: 77.30 test: 71.70
# [f18_i10_r03_c01_w5_1] Acc train: 91.10 test: 86.70
# [f18_i18_r00_c01_w5_1] Acc train: 85.80 test: 89.80
# [f19_i18_r00_c05_w4_1] Acc train: 73.90 test: 70.20
# [f20_i14_r06_c07_w5_1] Acc train: 72.50 test: 66.60
# [f21_i14_r07_c04_w6_1] Acc train: 55.00 test: 60.00
# [f22_i13_r04_c03_w6_1] Acc train: 71.20 test: 63.80
# [f23_i12_r10_c08_w4_1] Acc train: 69.70 test: 65.70
# [f23_i21_r01_c07_w4_1] Acc train: 66.20 test: 60.00
# [f24_i18_r06_c06_w6_1] Acc train: 76.70 test: 67.50
# [f25_i13_r09_c10_w5_1] Acc train: 54.80 test: 49.80
# [f25_i23_r02_c09_w5_1] Acc train: 54.80 test: 49.80
# [f26_i19_r01_c16_w5_1] Acc train: 55.00 test: 49.90
# [f27_i16_r03_c07_w6_1] Acc train: 55.20 test: 60.20
# [f27_i22_r00_c04_w5_1] Acc train: 80.80 test: 69.30
# [f28_i14_r13_c02_w4_1] Acc train: 81.70 test: 77.20
# [f28_i27_r01_c01_w4_1] Acc train: 92.80 test: 94.30
# [f29_i21_r08_c08_w6_1] Acc train: 54.90 test: 60.00
# [f29_i29_r00_c07_w5_1] Acc train: 54.90 test: 49.90
# [f30_i20_r09_c12_w5_1] Acc train: 54.90 test: 49.80
# [f30_i29_r00_c22_w6_1] Acc train: 54.70 test: 59.70
# Current poison rate: 0.10...
# [f04_i03_r00_c02_w5_1] Acc train: 76.90 test: 89.90
# [f07_i04_r01_c02_w5_1] Acc train: 70.40 test: 60.20
# [f08_i08_r00_c01_w5_1] Acc train: 82.30 test: 81.60
# [f10_i05_r05_c02_w6_1] Acc train: 69.80 test: 59.80
# [f10_i10_r00_c03_w5_1] Acc train: 70.80 test: 66.10
# [f12_i08_r04_c02_w4_1] Acc train: 69.80 test: 59.80
# [f13_i07_r03_c04_w4_1] Acc train: 70.00 test: 60.10
# [f14_i09_r01_c08_w4_1] Acc train: 52.90 test: 59.90
# [f15_i08_r06_c06_w5_1] Acc train: 59.90 test: 49.80
# [f16_i08_r00_c02_w6_1] Acc train: 69.70 test: 75.60
# [f17_i09_r03_c05_w6_1] Acc train: 61.10 test: 70.30
# [f18_i11_r00_c06_w4_1] Acc train: 63.70 test: 57.10
# [f18_i18_r00_c02_w4_1] Acc train: 61.90 test: 59.90
# [f19_i18_r00_c16_w5_1] Acc train: 60.00 test: 49.90
# [f20_i14_r06_c08_w4_1] Acc train: 65.70 test: 50.90
# [f21_i15_r00_c13_w5_1] Acc train: 60.00 test: 50.10
# [f22_i14_r00_c06_w4_1] Acc train: 56.40 test: 52.30
# [f23_i13_r04_c04_w5_1] Acc train: 60.00 test: 49.90
# [f23_i21_r02_c20_w6_1] Acc train: 65.10 test: 50.90
# [f24_i19_r01_c14_w5_1] Acc train: 60.20 test: 50.20
# [f25_i13_r12_c01_w4_1] Acc train: 83.50 test: 79.70
# [f26_i13_r07_c08_w4_1] Acc train: 55.30 test: 50.50
# [f26_i21_r04_c08_w5_1] Acc train: 60.20 test: 50.30
# [f27_i17_r01_c12_w6_1] Acc train: 61.60 test: 56.10
# [f27_i22_r03_c03_w6_1] Acc train: 53.10 test: 60.00
# [f28_i19_r03_c03_w5_1] Acc train: 59.90 test: 49.90
# [f28_i27_r01_c06_w6_1] Acc train: 65.10 test: 60.00
# [f29_i22_r03_c15_w4_1] Acc train: 63.90 test: 53.90
# [f29_i29_r00_c14_w4_1] Acc train: 69.50 test: 60.50
# [f30_i21_r03_c20_w5_1] Acc train: 59.90 test: 49.80
# [f30_i30_r00_c20_w5_1] Acc train: 60.00 test: 50.00
# Current poison rate: 0.15...
# [f04_i03_r01_c01_w6_1] Acc train: 89.40 test: 82.30
# [f07_i04_r01_c03_w6_1] Acc train: 75.60 test: 65.70
# [f08_i08_r00_c05_w4_1] Acc train: 71.40 test: 59.50
# [f10_i06_r00_c04_w5_1] Acc train: 70.80 test: 56.30
# [f10_i10_r00_c05_w4_1] Acc train: 71.10 test: 56.30
# [f12_i09_r00_c08_w4_1] Acc train: 74.90 test: 59.90
# [f13_i07_r05_c05_w5_1] Acc train: 65.10 test: 50.10
# [f14_i10_r01_c08_w4_1] Acc train: 75.50 test: 56.40
# [f15_i10_r04_c01_w6_1] Acc train: 77.70 test: 73.50
# [f16_i11_r03_c04_w4_1] Acc train: 75.20 test: 60.20
# [f17_i10_r05_c06_w5_1] Acc train: 65.20 test: 50.30
# [f18_i11_r07_c05_w6_1] Acc train: 74.90 test: 60.00
# [f19_i11_r06_c08_w5_1] Acc train: 76.50 test: 63.40
# [f20_i10_r06_c03_w4_1] Acc train: 75.10 test: 60.10
# [f20_i16_r01_c13_w6_1] Acc train: 74.80 test: 59.80
# [f21_i15_r02_c03_w4_1] Acc train: 74.70 test: 63.20
# [f22_i14_r05_c12_w6_1] Acc train: 65.10 test: 60.20
# [f23_i14_r03_c05_w6_1] Acc train: 65.80 test: 60.10
# [f23_i22_r00_c14_w6_1] Acc train: 74.70 test: 59.70
# [f24_i19_r05_c16_w4_1] Acc train: 67.90 test: 59.90
# [f25_i14_r07_c09_w4_1] Acc train: 71.80 test: 58.90
# [f26_i13_r11_c06_w6_1] Acc train: 74.90 test: 58.70
# [f26_i21_r05_c04_w4_1] Acc train: 74.50 test: 57.10
# [f27_i17_r04_c12_w4_1] Acc train: 71.80 test: 60.30
# [f27_i23_r02_c21_w6_1] Acc train: 73.60 test: 59.80
# [f28_i20_r00_c04_w6_1] Acc train: 74.80 test: 59.80
# [f29_i23_r04_c09_w6_1] Acc train: 74.90 test: 59.80
# [f30_i15_r10_c03_w6_1] Acc train: 65.80 test: 60.00
# [f30_i23_r04_c05_w5_1] Acc train: 65.00 test: 50.00
# Current poison rate: 0.20...
# Current poison rate: 0.25...
# [f05_i04_r00_c02_w6_1] Acc train: 79.30 test: 52.70
# [f07_i06_r00_c01_w6_1] Acc train: 89.80 test: 71.50
# [f09_i06_r00_c05_w4_1] Acc train: 83.20 test: 60.80
# [f10_i07_r00_c02_w6_1] Acc train: 78.30 test: 61.30
# [f11_i08_r02_c04_w4_1] Acc train: 76.10 test: 60.00
# [f12_i10_r01_c01_w5_1] Acc train: 75.10 test: 50.10
# [f13_i08_r05_c04_w6_1] Acc train: 82.20 test: 60.80
# [f14_i12_r02_c06_w6_1] Acc train: 86.20 test: 59.70
# [f15_i12_r02_c03_w5_1] Acc train: 75.00 test: 49.90
# [f16_i12_r01_c01_w4_1] Acc train: 81.90 test: 60.20
# [f17_i14_r02_c07_w5_1] Acc train: 75.00 test: 49.90
# [f18_i12_r05_c03_w4_1] Acc train: 65.70 test: 59.90
# [f19_i12_r07_c08_w5_1] Acc train: 75.10 test: 50.10
# [f20_i11_r08_c02_w6_1] Acc train: 82.20 test: 58.80
# [f20_i18_r01_c16_w4_1] Acc train: 81.10 test: 53.50
# [f21_i18_r00_c02_w6_1] Acc train: 79.50 test: 59.90
# [f22_i17_r02_c10_w5_1] Acc train: 75.00 test: 49.80
# [f23_i17_r00_c10_w6_1] Acc train: 84.70 test: 59.70
# [f24_i13_r02_c08_w4_1] Acc train: 83.20 test: 59.70
# [f24_i20_r02_c03_w6_1] Acc train: 76.90 test: 60.10
# [f25_i16_r08_c03_w5_1] Acc train: 75.00 test: 50.00
# [f26_i16_r06_c15_w4_1] Acc train: 81.80 test: 60.20
# [f26_i24_r00_c11_w4_1] Acc train: 85.20 test: 60.30
# [f27_i18_r00_c15_w4_1] Acc train: 84.90 test: 60.00
# [f27_i25_r00_c07_w6_1] Acc train: 84.50 test: 59.60
# [f28_i22_r01_c13_w5_1] Acc train: 75.00 test: 49.90
# [f29_i16_r04_c08_w5_1] Acc train: 75.00 test: 49.90
# [f29_i25_r01_c06_w5_1] Acc train: 74.90 test: 49.90
# [f30_i17_r02_c01_w6_1] Acc train: 83.10 test: 62.90
# [f30_i25_r00_c07_w4_1] Acc train: 84.90 test: 59.80
# Current poison rate: 0.30...
# [f05_i04_r01_c03_w4_1] Acc train: 85.70 test: 57.50
# [f07_i07_r00_c01_w4_1] Acc train: 89.70 test: 59.70
# [f09_i06_r03_c01_w5_1] Acc train: 83.10 test: 51.30
# [f10_i07_r00_c06_w5_1] Acc train: 80.00 test: 49.90
# [f11_i10_r00_c02_w5_1] Acc train: 80.00 test: 50.10
# [f12_i10_r02_c04_w6_1] Acc train: 80.40 test: 49.20
# [f13_i09_r02_c05_w6_1] Acc train: 78.90 test: 49.30
# [f14_i13_r01_c03_w6_1] Acc train: 85.10 test: 57.90
# [f15_i14_r00_c04_w4_1] Acc train: 70.00 test: 40.00
# [f16_i12_r01_c07_w5_1] Acc train: 82.90 test: 52.70
# [f17_i14_r03_c04_w4_1] Acc train: 83.30 test: 60.20
# [f18_i13_r00_c05_w5_1] Acc train: 80.10 test: 50.10
# [f19_i14_r04_c12_w5_1] Acc train: 80.20 test: 50.20
# [f20_i11_r08_c06_w4_1] Acc train: 78.30 test: 48.60
# [f20_i20_r00_c03_w4_1] Acc train: 66.00 test: 40.00
# [f21_i18_r03_c09_w5_1] Acc train: 80.30 test: 50.30
# [f22_i19_r03_c16_w5_1] Acc train: 79.80 test: 49.70
# [f23_i18_r04_c07_w5_1] Acc train: 80.00 test: 50.10
# [f24_i13_r05_c06_w6_1] Acc train: 85.50 test: 54.50
# [f24_i22_r02_c19_w6_1] Acc train: 70.00 test: 39.90
# [f25_i17_r05_c07_w6_1] Acc train: 89.90 test: 60.00
# [f26_i16_r08_c09_w5_1] Acc train: 80.00 test: 50.00
# [f26_i25_r00_c10_w5_1] Acc train: 80.00 test: 49.90
# [f27_i18_r05_c01_w5_1] Acc train: 80.30 test: 50.30
# [f27_i25_r01_c13_w5_1] Acc train: 80.00 test: 50.00
# [f28_i24_r01_c09_w4_1] Acc train: 76.90 test: 47.70
# [f29_i16_r08_c14_w6_1] Acc train: 70.20 test: 40.20
# [f29_i26_r00_c06_w5_1] Acc train: 80.00 test: 50.00
# [f30_i17_r13_c12_w4_1] Acc train: 69.90 test: 39.80
# [f30_i25_r04_c15_w6_1] Acc train: 70.10 test: 40.10
# Current poison rate: 0.35...
# [f05_i05_r00_c01_w6_1] Acc train: 96.10 test: 63.10
# [f07_i07_r00_c01_w5_1] Acc train: 91.70 test: 56.50
# [f09_i07_r00_c05_w4_1] Acc train: 84.10 test: 43.90
# [f10_i07_r01_c01_w4_1] Acc train: 85.20 test: 53.70
# [f11_i10_r01_c09_w4_1] Acc train: 84.50 test: 48.40
# [f12_i11_r00_c02_w4_1] Acc train: 89.30 test: 56.10
# [f13_i09_r04_c07_w5_1] Acc train: 85.00 test: 49.90
# [f14_i13_r01_c08_w4_1] Acc train: 88.70 test: 59.80
# [f15_i14_r01_c03_w6_1] Acc train: 90.50 test: 54.20
# [f16_i13_r00_c04_w4_1] Acc train: 84.60 test: 59.80
# [f17_i15_r01_c08_w4_1] Acc train: 93.20 test: 58.10
# [f18_i15_r02_c12_w5_1] Acc train: 85.00 test: 50.10
# [f19_i14_r05_c01_w4_1] Acc train: 89.60 test: 54.70
# [f20_i12_r00_c01_w6_1] Acc train: 74.90 test: 39.90
# [f21_i11_r03_c07_w5_1] Acc train: 85.10 test: 50.20
# [f21_i20_r01_c11_w6_1] Acc train: 85.30 test: 60.10
# [f22_i20_r00_c10_w5_1] Acc train: 84.90 test: 49.80
# [f23_i18_r04_c13_w6_1] Acc train: 91.80 test: 60.00
# [f24_i15_r03_c03_w5_1] Acc train: 84.80 test: 49.80
# [f24_i23_r00_c05_w6_1] Acc train: 94.90 test: 59.90
# [f25_i17_r07_c15_w4_1] Acc train: 87.70 test: 60.10
# [f26_i17_r01_c05_w5_1] Acc train: 85.00 test: 50.10
# [f26_i26_r00_c09_w5_1] Acc train: 84.80 test: 49.70
# [f27_i18_r09_c03_w6_1] Acc train: 80.00 test: 60.00
# [f27_i26_r00_c20_w6_1] Acc train: 95.10 test: 60.00
# [f28_i24_r02_c07_w5_1] Acc train: 85.00 test: 49.90
# [f29_i18_r04_c11_w6_1] Acc train: 92.30 test: 57.70
# [f29_i26_r02_c10_w4_1] Acc train: 94.80 test: 59.80
# [f30_i18_r04_c04_w5_1] Acc train: 85.00 test: 49.90
# [f30_i27_r00_c02_w4_1] Acc train: 75.10 test: 40.00
# Current poison rate: 0.40...
# [f05_i05_r00_c03_w5_1] Acc train: 89.90 test: 49.90
# [f07_i07_r00_c01_w6_1] Acc train: 92.10 test: 53.40
# [f09_i07_r01_c04_w5_1] Acc train: 90.10 test: 50.10
# [f10_i08_r00_c04_w4_1] Acc train: 92.60 test: 53.50
# [f11_i11_r00_c10_w6_1] Acc train: 88.90 test: 52.60
# [f12_i11_r00_c09_w5_1] Acc train: 90.50 test: 50.50
# [f13_i11_r00_c01_w5_1] Acc train: 89.20 test: 50.50
# [f14_i13_r01_c08_w5_1] Acc train: 90.10 test: 50.10
# [f15_i15_r00_c03_w5_1] Acc train: 89.90 test: 49.90
# [f17_i15_r01_c10_w6_1] Acc train: 82.00 test: 44.70
# [f18_i15_r03_c04_w4_1] Acc train: 88.00 test: 45.90
# [f19_i15_r03_c06_w5_1] Acc train: 90.00 test: 49.90
# [f20_i12_r04_c03_w4_1] Acc train: 87.30 test: 60.00
# [f21_i12_r01_c11_w5_1] Acc train: 90.00 test: 49.90
# [f21_i21_r00_c03_w6_1] Acc train: 80.20 test: 40.30
# [f22_i20_r01_c03_w6_1] Acc train: 80.00 test: 39.90
# [f23_i19_r01_c18_w6_1] Acc train: 83.60 test: 42.40
# [f24_i15_r05_c14_w6_1] Acc train: 84.10 test: 45.00
# [f24_i23_r00_c11_w4_1] Acc train: 79.80 test: 39.80
# [f25_i19_r01_c02_w4_1] Acc train: 79.80 test: 39.90
# [f26_i17_r04_c12_w6_1] Acc train: 80.20 test: 40.10
# [f26_i26_r00_c21_w4_1] Acc train: 80.20 test: 40.20
# [f27_i19_r04_c10_w6_1] Acc train: 81.10 test: 42.60
# [f27_i27_r00_c16_w4_1] Acc train: 79.90 test: 39.80
# [f28_i25_r02_c24_w4_1] Acc train: 79.90 test: 39.80
# [f29_i19_r05_c10_w4_1] Acc train: 91.10 test: 51.30
# [f29_i27_r00_c01_w6_1] Acc train: 86.60 test: 60.10
# [f30_i19_r03_c01_w6_1] Acc train: 99.80 test: 59.90
# [f30_i27_r01_c01_w6_1] Acc train: 79.90 test: 40.10

# %%
df_cm[df_cm['Train'] == 0]
# Out:
# Empty DataFrame
# Columns: [Data, F1, F1 SD, F1v, F2, F3, F4, N1, N2, N2 SD, N3 , N3 SD, N4, N4 SD, T1, T1 SD, LSC, L1, L2, L3, T2, T3, T4, C1, C2, Density, ClsCoef, Hubs, HubsSD, Rate, Filepath, Testpath, Train, Test]
# Index: []
#
# [0 rows x 34 columns]

# %%
df_cm.to_csv(os.path.join(PATH_ROOT, 'results', 'synth_cmeasures_nn.csv'), index=False)
