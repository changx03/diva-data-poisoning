# %%
import os
from pathlib import Path
from glob import glob

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

from label_flip_revised.utils import open_csv, create_dir
from label_flip_revised.simple_nn_model import SimpleModel
from label_flip_revised.torch_utils import evaluate, train_model

# %%
PATH_ROOT = Path(os.getcwd()).absolute().parent
print(PATH_ROOT)
# Out:
# /home/lukec/workspace/label_flip_revised

# %% [markdown]
# ## Plot correlations between C-Measures and Test accuracy on 20% poisoned data

# %%
path_cm_poison = glob(os.path.join(PATH_ROOT, 'results', 'synth_nn', '*.csv'))
print(path_cm_poison[:5])
# Out:
# ['/home/lukec/workspace/label_flip_revised/results/synth_nn/synth_nn_poison_32.csv', '/home/lukec/workspace/label_flip_revised/results/synth_nn/synth_nn_poison_43.csv', '/home/lukec/workspace/label_flip_revised/results/synth_nn/synth_nn_poison_6.csv', '/home/lukec/workspace/label_flip_revised/results/synth_nn/synth_nn_poison_31.csv', '/home/lukec/workspace/label_flip_revised/results/synth_nn/synth_nn_poison_17.csv']

# %%
df_c_measure = pd.DataFrame()
for p in path_cm_poison:
    _df = pd.read_csv(p)
    df_c_measure = pd.concat([df_c_measure, _df])

df_c_measure
# Out:
#                                      Data  overlapping.F1.mean  \
# 0   f23_i19_r03_c12_w4_1_nn_ALFA_0.40.csv             0.971368
# 1   f23_i19_r03_c12_w4_1_nn_ALFA_0.45.csv             0.991248
# 2   f23_i20_r01_c04_w6_1_nn_ALFA_0.05.csv             0.978715
# 3   f23_i20_r01_c04_w6_1_nn_ALFA_0.10.csv             0.994083
# 4   f23_i20_r01_c04_w6_1_nn_ALFA_0.15.csv             0.975035
# ..                                    ...                  ...
# 45  f20_i13_r06_c08_w6_1_nn_ALFA_0.20.csv             0.973313
# 46  f20_i13_r06_c08_w6_1_nn_ALFA_0.25.csv             0.968516
# 47  f20_i13_r06_c08_w6_1_nn_ALFA_0.30.csv             0.966669
# 48  f20_i13_r06_c08_w6_1_nn_ALFA_0.35.csv             0.986961
# 49  f20_i13_r06_c08_w6_1_nn_ALFA_0.40.csv             0.963904
#
#     overlapping.F1.sd  overlapping.F1v.mean  overlapping.F1v.sd  \
# 0            0.047773              0.220999                 NaN
# 1            0.013806              0.161720                 NaN
# 2            0.024991              0.363609                 NaN
# 3            0.008163              0.694670                 NaN
# 4            0.040759              0.319944                 NaN
# ..                ...                   ...                 ...
# 45           0.033234              0.422462                 NaN
# 46           0.046097              0.286151                 NaN
# 47           0.043208              0.322280                 NaN
# 48           0.018868              0.259292                 NaN
# 49           0.052183              0.247531                 NaN
#
#     overlapping.F2.mean  overlapping.F2.sd  overlapping.F3.mean  \
# 0          3.752426e-03                NaN                0.746
# 1          1.605055e-10                NaN                0.196
# 2          2.967728e-02                NaN                0.975
# 3          3.853505e-02                NaN                0.979
# 4          3.214801e-02                NaN                0.817
# ..                  ...                ...                  ...
# 45         9.419490e-02                NaN                0.942
# 46         5.460055e-03                NaN                0.746
# 47         2.590895e-02                NaN                0.816
# 48         1.837886e-06                NaN                0.473
# 49         9.028955e-03                NaN                0.734
#
#     overlapping.F3.sd  overlapping.F4.mean  ...  linearity.L3.sd  \
# 0                 NaN                0.419  ...              NaN
# 1                 NaN                0.000  ...              NaN
# 2                 NaN                0.815  ...              NaN
# 3                 NaN                0.835  ...              NaN
# 4                 NaN                0.693  ...              NaN
# ..                ...                  ...  ...              ...
# 45                NaN                0.826  ...              NaN
# 46                NaN                0.455  ...              NaN
# 47                NaN                0.646  ...              NaN
# 48                NaN                0.048  ...              NaN
# 49                NaN                0.468  ...              NaN
#
#     dimensionality.T2  dimensionality.T3  dimensionality.T4  balance.C1  \
# 0               0.023              0.017           0.739130    0.727888
# 1               0.023              0.017           0.739130    0.163346
# 2               0.023              0.019           0.826087    0.993061
# 3               0.023              0.019           0.826087    0.913901
# 4               0.023              0.019           0.826087    0.991880
# ..                ...                ...                ...         ...
# 45              0.020              0.011           0.550000    0.970363
# 46              0.020              0.011           0.550000    0.727888
# 47              0.020              0.011           0.550000    0.880065
# 48              0.020              0.011           0.550000    0.290630
# 49              0.020              0.011           0.550000    0.719924
#
#     balance.C2  network.Density  network.ClsCoef  network.Hubs.mean  \
# 0     0.521624         0.855928         0.598085           0.653758
# 1     0.950849         0.816601         0.620984           0.494284
# 2     0.019025         0.889818         0.565411           0.798096
# 3     0.209432         0.888312         0.590123           0.732069
# 4     0.022222         0.882891         0.548638           0.779119
# ..         ...              ...              ...                ...
# 45    0.078409         0.890721         0.563365           0.706424
# 46    0.521624         0.868028         0.580758           0.545219
# 47    0.278243         0.880120         0.571693           0.607845
# 48    0.892828         0.833594         0.595120           0.418129
# 49    0.532007         0.863530         0.578086           0.475697
#
#     network.Hubs.sd
# 0          0.219798
# 1          0.135896
# 2          0.268392
# 3          0.215619
# 4          0.252366
# ..              ...
# 45         0.274715
# 46         0.265855
# 47         0.288763
# 48         0.158548
# 49         0.288330
#
# [2619 rows x 36 columns]

# %%
# Remove NA
print('# of columns before removing NA:', len(df_c_measure.columns) - 1)  # Name does not count
cols_not_na = df_c_measure.columns[df_c_measure.notna().any()].tolist()
df_c_measure = df_c_measure[cols_not_na]
print('# of columns after removing NA:', len(df_c_measure.columns) - 1)  # Name does not count
print(cols_not_na)
# Out:
# # of columns before removing NA: 35
# # of columns after removing NA: 28
# ['Data', 'overlapping.F1.mean', 'overlapping.F1.sd', 'overlapping.F1v.mean', 'overlapping.F2.mean', 'overlapping.F3.mean', 'overlapping.F4.mean', 'neighborhood.N1', 'neighborhood.N2.mean', 'neighborhood.N2.sd', 'neighborhood.N3.mean', 'neighborhood.N3.sd', 'neighborhood.N4.mean', 'neighborhood.N4.sd', 'neighborhood.T1.mean', 'neighborhood.T1.sd', 'neighborhood.LSC', 'linearity.L1.mean', 'linearity.L2.mean', 'linearity.L3.mean', 'dimensionality.T2', 'dimensionality.T3', 'dimensionality.T4', 'balance.C1', 'balance.C2', 'network.Density', 'network.ClsCoef', 'network.Hubs.mean', 'network.Hubs.sd']

# %%
# Rename Columns
new_cols = [
    'Data', 'F1', 'F1 SD', 'F1v', 'F2', 'F3', 'F4', 'N1', 
    'N2', 'N2 SD', 'N3 ', 'N3 SD', 'N4', 'N4 SD', 'T1', 'T1 SD', 'LSC', 
    'L1', 'L2', 'L3', 'T2', 'T3', 'T4', 'C1', 'C2', 'Density', 'ClsCoef', 
    'Hubs', 'HubsSD']
new_names_map = {df_c_measure.columns[i]:new_cols[i] for i in range(len(new_cols))}

df_c_measure.rename(new_names_map, axis=1, inplace=True)

df_c_measure.head()
# Out:
# /home/lukec/venv/torch/lib/python3.8/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#                                     Data        F1     F1 SD       F1v  \
# 0  f23_i19_r03_c12_w4_1_nn_ALFA_0.40.csv  0.971368  0.047773  0.220999
# 1  f23_i19_r03_c12_w4_1_nn_ALFA_0.45.csv  0.991248  0.013806  0.161720
# 2  f23_i20_r01_c04_w6_1_nn_ALFA_0.05.csv  0.978715  0.024991  0.363609
# 3  f23_i20_r01_c04_w6_1_nn_ALFA_0.10.csv  0.994083  0.008163  0.694670
# 4  f23_i20_r01_c04_w6_1_nn_ALFA_0.15.csv  0.975035  0.040759  0.319944
#
#              F2     F3     F4     N1        N2     N2 SD  ...     L3     T2  \
# 0  3.752426e-03  0.746  0.419  0.264  0.449515  0.051618  ...  0.101  0.023
# 1  1.605055e-10  0.196  0.000  0.054  0.399730  0.055234  ...  0.001  0.023
# 2  2.967728e-02  0.975  0.815  0.294  0.460189  0.043083  ...  0.196  0.023
# 3  3.853505e-02  0.979  0.835  0.333  0.467090  0.042345  ...  0.335  0.023
# 4  3.214801e-02  0.817  0.693  0.298  0.459409  0.048499  ...  0.182  0.023
#
#       T3        T4        C1        C2   Density   ClsCoef      Hubs    HubsSD
# 0  0.017  0.739130  0.727888  0.521624  0.855928  0.598085  0.653758  0.219798
# 1  0.017  0.739130  0.163346  0.950849  0.816601  0.620984  0.494284  0.135896
# 2  0.019  0.826087  0.993061  0.019025  0.889818  0.565411  0.798096  0.268392
# 3  0.019  0.826087  0.913901  0.209432  0.888312  0.590123  0.732069  0.215619
# 4  0.019  0.826087  0.991880  0.022222  0.882891  0.548638  0.779119  0.252366
#
# [5 rows x 29 columns]

# %%
rates = [float(Path(d).stem.split('_')[-1]) for d in df_c_measure['Data'].to_list()]
df_c_measure['rate'] = rates
# Out:
# /tmp/ipykernel_20284/1600742863.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c_measure['rate'] = rates

# %%
RATE = 0.2

# %%
df_cm_rate = df_c_measure[df_c_measure['rate'] == RATE]
print(len(df_cm_rate))
df_cm_rate.head()
# Out:
# 300
#                                      Data        F1     F1 SD       F1v  \
# 5   f23_i20_r01_c04_w6_1_nn_ALFA_0.20.csv  0.984303  0.029797  0.352579
# 14  f23_i21_r01_c07_w4_1_nn_ALFA_0.20.csv  0.982818  0.030531  0.409066
# 22  f23_i21_r02_c20_w6_1_nn_ALFA_0.20.csv  0.978988  0.032149  0.402180
# 30  f23_i22_r00_c14_w6_1_nn_ALFA_0.20.csv  0.991892  0.008891  0.540062
# 38  f24_i12_r01_c02_w4_1_nn_ALFA_0.20.csv  0.978861  0.030482  0.312407
#
#           F2     F3     F4     N1        N2     N2 SD  ...     T2     T3  \
# 5   0.010227  0.748  0.557  0.229  0.444759  0.052260  ...  0.023  0.019
# 14  0.052753  0.764  0.669  0.388  0.462677  0.047797  ...  0.023  0.020
# 22  0.038876  0.932  0.789  0.410  0.472714  0.042198  ...  0.023  0.019
# 30  0.062306  0.980  0.868  0.506  0.483945  0.033509  ...  0.023  0.021
# 38  0.056246  0.962  0.802  0.301  0.465471  0.038507  ...  0.024  0.019
#
#           T4        C1        C2   Density   ClsCoef      Hubs    HubsSD  rate
# 5   0.826087  0.727888  0.521624  0.861984  0.594752  0.708287  0.199847   0.2
# 14  0.869565  0.969169  0.081417  0.880977  0.548306  0.748148  0.265577   0.2
# 22  0.826087  0.971533  0.075450  0.884290  0.566951  0.765659  0.248525   0.2
# 30  0.913043  0.969169  0.081417  0.908705  0.696349  0.635698  0.307014   0.2
# 38  0.791667  0.972109  0.073990  0.879946  0.546931  0.682979  0.287819   0.2
#
# [5 rows x 30 columns]

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
    print('Running on CPU!')

HIDDEN_LAYER = 128
LR = 0.001  # Learning rate.
MAX_EPOCHS = 400  # Number of iteration for training.
BATCH_SIZE = 128

# %%
def get_dataloader(X, y, batch_size=BATCH_SIZE, shuffle=True):
    dataset = TensorDataset(torch.from_numpy(X).type(torch.float32),
                                  torch.from_numpy(y).type(torch.int64))
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=shuffle)
    return dataloader

# %%
path_output = os.path.join(PATH_ROOT, 'results')
path_model = os.path.join(path_output, 'torch')
create_dir(path_model)

# %%
path_plot = os.path.join(path_output, f'synth_falfa_{RATE:.2f}_score.csv')

acc_train = []
acc_test = []
datanames = []

if os.path.exists(path_plot):
    df = pd.read_csv(path_plot)
    acc_train = df['train'].to_list()
    acc_test = df['test'].to_list()
    datanames = df['data'].to_list()
else:
    postfix_clean = '_clean_test.csv'
    postfix_torch = '_SimpleNN.torch'

    for i in tqdm(range(df_cm_rate.shape[0])):
        dataname_poison = str(Path(df_cm_rate.iloc[i]['Data']).stem)
        dataname = dataname_poison[:-len('_nn_ALFA_0.20')]
        datanames.append(dataname)
        
        X_po, y_po, _ = open_csv(os.path.join(PATH_ROOT, 'data', 'synth', 'alfa_nn', f'{dataname_poison}.csv'))
        X_test, y_test, _ = open_csv(os.path.join(PATH_ROOT, 'data', 'synth', 'test', f'{dataname}{postfix_clean}'))
        n_features = X_po.shape[1]

        dataloader_poison = get_dataloader(X_po, y_po, shuffle=True)
        dataloader_test = get_dataloader(X_test, y_test, shuffle=False)

        model = SimpleModel(n_features, hidden_dim=HIDDEN_LAYER, output_dim=2).to(device)
        optimizer = torch.optim.SGD(model.parameters(), lr=LR, momentum=0.8)
        loss_fn = nn.CrossEntropyLoss()

        _path_model = os.path.join(path_model, f'{dataname_poison}{postfix_torch}')
        if os.path.exists(_path_model):
            model.load_state_dict(torch.load(_path_model, map_location=device))
        else:
            train_model(model, dataloader_poison, optimizer, loss_fn, device, MAX_EPOCHS)
            torch.save(model.state_dict(), _path_model)

        acc_po, _ = evaluate(dataloader_poison, model, loss_fn, device)
        acc_te, _ = evaluate(dataloader_test, model, loss_fn, device)
        acc_train.append(acc_po)
        acc_test.append(acc_te)

        if i % 10 == 0:
            print(f'[{dataname}] Acc train: {acc_po*100:.2f} test: {acc_te*100:.2f}')

    results = {
        'data': datanames,
        'train': acc_train,
        'test': acc_test,
    }
    df = pd.DataFrame(results)
    df.to_csv(os.path.join(path_output, f'synth_falfa_{RATE:.2f}_score.csv'), index=False)

# %%
cols = [
    'F1', 'F1 SD', 'F1v', 'F2', 'F3', 'F4', 'N1', 
    'N2', 'N2 SD', 'N3 ', 'N3 SD', 'N4', 'N4 SD', 'T1', 'T1 SD', 'LSC', 
    'L1', 'L2', 'L3', 'T2', 'T3', 'T4', 'C1', 'C2', 'Density', 'ClsCoef', 
    'Hubs', 'HubsSD']

# %%
figsize=(10, 4)
fontsize = 14
plt.rcParams["font.size"] = fontsize

# %%
df_cm_rate = df_cm_rate[cols]
df_cm_rate['acc.test'] = acc_test

cor = df_cm_rate[cols + ['acc.test']].corr()
cor_test = cor['acc.test']

plt.figure(figsize=figsize)
cor_test[cor_test.abs().sort_values(ascending=False).keys()[1:]].plot.bar()
plt.title('')
plt.ylim([-1.05, 1.05])
plt.tight_layout()
path_fig = os.path.join(path_output, 'synth_cor_acc_test_falfa_0.20.pdf')
plt.savefig(path_fig, dpi=300)

path_output = os.path.join(PATH_ROOT, 'results', 'synth_cor_acc_test_falfa_0.20.csv')
cor_test.to_csv(path_output, index=True)

# %%
df_cm_rate = df_cm_rate[cols]
df_cm_rate['acc.train'] = acc_train

cor = df_cm_rate.corr()
cor_train = cor['acc.train']

plt.figure(figsize=figsize)
cor_train[cor_train.abs().sort_values(ascending=False).keys()[1:]].plot.bar()
plt.title('')
plt.ylim([-1.05, 1.05])
plt.tight_layout()
path_fig = os.path.join(PATH_ROOT, 'results', 'synth_cor_acc_train_falfa_0.20.pdf')
plt.savefig(path_fig, dpi=300)

path_output = os.path.join(PATH_ROOT, 'results', 'synth_cor_acc_train_falfa_0.20.csv')
cor_train.to_csv(path_output, index=True)

# %%
np.mean(np.abs((cor_train - cor_test) / cor_test))
# Out:
# 0.1713895911865003
