# %%
import os
from pathlib import Path
from glob import glob

import numpy as np
import pandas as pd
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler

from label_flip_revised.utils import (create_dir, open_csv, open_json)

# %%
PATH_ROOT = Path(os.getcwd()).absolute().parent
print(PATH_ROOT)
# Out:
# /home/lukec/workspace/label_flip_revised

# %%
# NOTE: `cardiotocography` is removed!

datanames = [
    'abalone_subset_std',
    'australian_std',
    'banknote_std',
    'breastcancer_std',
    'cmc_std',
    'htru2_subset_std',
    'phoneme_subset_std',
    'ringnorm_subset_std',
    'texture_subset_std',
    'yeast_subset_std'
]

print(len(datanames))
# Out:
# 10

# %%
poison_rate = [f'{i:.2f}' for i in np.arange(0.0, 0.41, 0.05)]
poison_rate
# Out:
# ['0.00', '0.05', '0.10', '0.15', '0.20', '0.25', '0.30', '0.35', '0.40']

# %%
path_train = os.path.join(PATH_ROOT, 'data', 'output', 'train', '*.csv')
datapath_train = np.sort(glob(path_train))
print(len(datapath_train))
datapath_train
# Out:
# 11
# array(['/home/lukec/workspace/label_flip_revised/data/output/train/abalone_subset_std_clean_train.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/train/australian_std_clean_train.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/train/banknote_std_clean_train.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/train/breastcancer_std_clean_train.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/train/cardiotocography_std_clean_train.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/train/cmc_std_clean_train.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/train/htru2_subset_std_clean_train.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/train/phoneme_subset_std_clean_train.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/train/ringnorm_subset_std_clean_train.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/train/texture_subset_std_clean_train.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/train/yeast_subset_std_clean_train.csv'],
#       dtype='<U95')

# %%
path_test = os.path.join(PATH_ROOT, 'data', 'output', 'test', '*.csv')
datapath_test = np.sort(glob(path_test))
print(len(datapath_test))
datapath_test
# Out:
# 11
# array(['/home/lukec/workspace/label_flip_revised/data/output/test/abalone_subset_std_clean_test.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/test/australian_std_clean_test.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/test/banknote_std_clean_test.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/test/breastcancer_std_clean_test.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/test/cardiotocography_std_clean_test.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/test/cmc_std_clean_test.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/test/htru2_subset_std_clean_test.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/test/phoneme_subset_std_clean_test.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/test/ringnorm_subset_std_clean_test.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/test/texture_subset_std_clean_test.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/test/yeast_subset_std_clean_test.csv'],
#       dtype='<U93')

# %%
path_alfa = os.path.join(PATH_ROOT, 'data', 'output', 'alfa', '*.csv')
datapath_alfa = np.sort(glob(path_alfa))
print(len(datapath_alfa))
datapath_alfa[:10]
# Out:
# 99
# array(['/home/lukec/workspace/label_flip_revised/data/output/alfa/abalone_subset_std_rbf_ALFA_0.05.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/alfa/abalone_subset_std_rbf_ALFA_0.10.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/alfa/abalone_subset_std_rbf_ALFA_0.15.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/alfa/abalone_subset_std_rbf_ALFA_0.20.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/alfa/abalone_subset_std_rbf_ALFA_0.25.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/alfa/abalone_subset_std_rbf_ALFA_0.30.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/alfa/abalone_subset_std_rbf_ALFA_0.35.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/alfa/abalone_subset_std_rbf_ALFA_0.40.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/alfa/abalone_subset_std_rbf_ALFA_0.45.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/alfa/australian_std_rbf_ALFA_0.05.csv'],
#       dtype='<U96')

# %%
path_flfa = os.path.join(PATH_ROOT, 'data', 'output', 'alfa_nn', '*.csv')
datapath_flfa = np.sort(glob(path_flfa))
print(len(datapath_flfa))
datapath_flfa[:10]
# Out:
# 95
# array(['/home/lukec/workspace/label_flip_revised/data/output/alfa_nn/abalone_subset_std_nn_ALFA_0.05.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/alfa_nn/abalone_subset_std_nn_ALFA_0.10.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/alfa_nn/abalone_subset_std_nn_ALFA_0.15.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/alfa_nn/abalone_subset_std_nn_ALFA_0.20.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/alfa_nn/abalone_subset_std_nn_ALFA_0.25.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/alfa_nn/abalone_subset_std_nn_ALFA_0.30.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/alfa_nn/abalone_subset_std_nn_ALFA_0.35.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/alfa_nn/abalone_subset_std_nn_ALFA_0.40.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/alfa_nn/abalone_subset_std_nn_ALFA_0.45.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/alfa_nn/australian_std_nn_ALFA_0.05.csv'],
#       dtype='<U98')

# %%
path_random = os.path.join(PATH_ROOT, 'data', 'output', 'random', '*.csv')
datapath_random = np.sort(glob(path_random))
print(len(datapath_random))
datapath_random[:10]
# Out:
# 88
# array(['/home/lukec/workspace/label_flip_revised/data/output/random/abalone_subset_std_random_0.05.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/random/abalone_subset_std_random_0.10.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/random/abalone_subset_std_random_0.15.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/random/abalone_subset_std_random_0.20.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/random/abalone_subset_std_random_0.25.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/random/abalone_subset_std_random_0.30.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/random/abalone_subset_std_random_0.35.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/random/abalone_subset_std_random_0.40.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/random/australian_std_random_0.05.csv',
#        '/home/lukec/workspace/label_flip_revised/data/output/random/australian_std_random_0.10.csv'],
#       dtype='<U96')

# %%
path_output = os.path.join(PATH_ROOT, 'results', 'real')
create_dir(path_output)

for j, dataname in enumerate(datanames):
    print(dataname)
    acc_train = []
    acc_test = []

    path_json_param = os.path.join(PATH_ROOT, 'data', 'output', 'alfa', dataname + '_svm.json')
    svm_param = open_json(path_json_param)

    path_data_test = os.path.join(PATH_ROOT, 'data', 'output', 'test', dataname + '_clean_test.csv')
    X_test, y_test, _ = open_csv(path_data_test)

    path_data_train_list = [f for f in datapath_train if dataname in f] + [f for f in datapath_alfa if dataname in f]
    print(len(path_data_train_list))

    for i, p in enumerate(poison_rate):
        X_train, y_train, _ = open_csv(path_data_train_list[i])
        clf = SVC(**svm_param)
        clf.fit(X_train, y_train)
        acc_train.append(clf.score(X_train, y_train))
        acc_test.append(clf.score(X_test, y_test))
        print(f'Accuracy on {p}% poison data train: {acc_train[i] * 100:.2f} test: {acc_test[i] * 100:.2f}')
    
    results = {
        'rate': poison_rate,
        'train': acc_train,
        'test': acc_test,
    }
    df = pd.DataFrame(results)
    df.to_csv(os.path.join(path_output, f'{dataname}_svm_alfa_score.csv'), index=False)
# Out:
# abalone_subset_std
# 10
# Accuracy on 0.00% poison data train: 81.44 test: 78.75
# Accuracy on 0.05% poison data train: 78.56 test: 77.00
# Accuracy on 0.10% poison data train: 78.00 test: 69.50
# Accuracy on 0.15% poison data train: 79.88 test: 67.00
# Accuracy on 0.20% poison data train: 78.00 test: 59.50
# Accuracy on 0.25% poison data train: 78.62 test: 57.25
# Accuracy on 0.30% poison data train: 77.75 test: 53.75
# Accuracy on 0.35% poison data train: 81.69 test: 51.00
# Accuracy on 0.40% poison data train: 78.88 test: 43.75
# australian_std
# 10
# Accuracy on 0.00% poison data train: 87.14 test: 90.58
# Accuracy on 0.05% poison data train: 80.43 test: 85.51
# Accuracy on 0.10% poison data train: 84.60 test: 68.12
# Accuracy on 0.15% poison data train: 83.88 test: 70.29
# Accuracy on 0.20% poison data train: 64.49 test: 44.20
# Accuracy on 0.25% poison data train: 69.57 test: 44.20
# Accuracy on 0.30% poison data train: 74.46 test: 44.20
# Accuracy on 0.35% poison data train: 79.53 test: 44.20
# Accuracy on 0.40% poison data train: 84.42 test: 44.20
# banknote_std
# 10
# Accuracy on 0.00% poison data train: 100.00 test: 100.00
# Accuracy on 0.05% poison data train: 97.90 test: 95.27
# Accuracy on 0.10% poison data train: 97.27 test: 89.82
# Accuracy on 0.15% poison data train: 95.35 test: 88.00
# Accuracy on 0.20% poison data train: 92.53 test: 83.27
# Accuracy on 0.25% poison data train: 95.17 test: 74.18
# Accuracy on 0.30% poison data train: 94.99 test: 68.36
# Accuracy on 0.35% poison data train: 92.89 test: 62.55
# Accuracy on 0.40% poison data train: 94.71 test: 60.36
# breastcancer_std
# 10
# Accuracy on 0.00% poison data train: 98.90 test: 99.12
# Accuracy on 0.05% poison data train: 98.24 test: 94.74
# Accuracy on 0.10% poison data train: 97.58 test: 87.72
# Accuracy on 0.15% poison data train: 97.14 test: 79.82
# Accuracy on 0.20% poison data train: 96.04 test: 72.81
# Accuracy on 0.25% poison data train: 92.31 test: 71.93
# Accuracy on 0.30% poison data train: 90.55 test: 64.04
# Accuracy on 0.35% poison data train: 92.97 test: 62.28
# Accuracy on 0.40% poison data train: 93.63 test: 58.77
# cmc_std
# 10
# Accuracy on 0.00% poison data train: 77.42 test: 77.29
# Accuracy on 0.05% poison data train: 77.59 test: 73.22
# Accuracy on 0.10% poison data train: 82.60 test: 73.22
# Accuracy on 0.15% poison data train: 81.75 test: 71.19
# Accuracy on 0.20% poison data train: 84.80 test: 67.80
# Accuracy on 0.25% poison data train: 85.82 test: 62.71
# Accuracy on 0.30% poison data train: 87.35 test: 60.68
# Accuracy on 0.35% poison data train: 88.37 test: 55.93
# Accuracy on 0.40% poison data train: 87.78 test: 51.86
# htru2_subset_std
# 10
# Accuracy on 0.00% poison data train: 94.69 test: 92.50
# Accuracy on 0.05% poison data train: 94.44 test: 86.75
# Accuracy on 0.10% poison data train: 94.31 test: 80.75
# Accuracy on 0.15% poison data train: 94.38 test: 74.50
# Accuracy on 0.20% poison data train: 94.19 test: 67.25
# Accuracy on 0.25% poison data train: 93.88 test: 64.75
# Accuracy on 0.30% poison data train: 92.94 test: 59.50
# Accuracy on 0.35% poison data train: 92.44 test: 54.25
# Accuracy on 0.40% poison data train: 93.38 test: 50.75
# phoneme_subset_std
# 10
# Accuracy on 0.00% poison data train: 87.81 test: 82.75
# Accuracy on 0.05% poison data train: 87.25 test: 77.75
# Accuracy on 0.10% poison data train: 86.12 test: 70.75
# Accuracy on 0.15% poison data train: 85.88 test: 65.50
# Accuracy on 0.20% poison data train: 86.12 test: 63.75
# Accuracy on 0.25% poison data train: 86.00 test: 58.00
# Accuracy on 0.30% poison data train: 85.81 test: 52.75
# Accuracy on 0.35% poison data train: 88.25 test: 51.50
# Accuracy on 0.40% poison data train: 86.50 test: 46.00
# ringnorm_subset_std
# 10
# Accuracy on 0.00% poison data train: 99.12 test: 96.00
# Accuracy on 0.05% poison data train: 93.38 test: 91.75
# Accuracy on 0.10% poison data train: 89.94 test: 84.50
# Accuracy on 0.15% poison data train: 89.44 test: 79.25
# Accuracy on 0.20% poison data train: 87.62 test: 70.75
# Accuracy on 0.25% poison data train: 87.31 test: 63.00
# Accuracy on 0.30% poison data train: 87.38 test: 59.50
# Accuracy on 0.35% poison data train: 87.56 test: 52.50
# Accuracy on 0.40% poison data train: 90.00 test: 50.00
# texture_subset_std
# 10
# Accuracy on 0.00% poison data train: 100.00 test: 100.00
# Accuracy on 0.05% poison data train: 99.88 test: 92.50
# Accuracy on 0.10% poison data train: 99.75 test: 87.00
# Accuracy on 0.15% poison data train: 99.88 test: 80.50
# Accuracy on 0.20% poison data train: 99.88 test: 76.50
# Accuracy on 0.25% poison data train: 99.62 test: 66.00
# Accuracy on 0.30% poison data train: 99.88 test: 63.00
# Accuracy on 0.35% poison data train: 100.00 test: 54.50
# Accuracy on 0.40% poison data train: 99.88 test: 50.50
# yeast_subset_std
# 10
# Accuracy on 0.00% poison data train: 70.97 test: 65.92
# Accuracy on 0.05% poison data train: 69.85 test: 61.45
# Accuracy on 0.10% poison data train: 72.79 test: 60.89
# Accuracy on 0.15% poison data train: 73.07 test: 56.98
# Accuracy on 0.20% poison data train: 72.37 test: 58.10
# Accuracy on 0.25% poison data train: 74.89 test: 53.63
# Accuracy on 0.30% poison data train: 69.28 test: 43.02
# Accuracy on 0.35% poison data train: 70.97 test: 34.08
# Accuracy on 0.40% poison data train: 73.77 test: 34.64

# %%
path_output = os.path.join(PATH_ROOT, 'results', 'real')
create_dir(path_output)

for j, dataname in enumerate(datanames):
    print(dataname)
    acc_train = []
    acc_test = []

    path_json_param = os.path.join(PATH_ROOT, 'data', 'output', 'alfa', dataname + '_svm.json')
    svm_param = open_json(path_json_param)

    path_data_test = os.path.join(PATH_ROOT, 'data', 'output', 'test', dataname + '_clean_test.csv')
    X_test, y_test, _ = open_csv(path_data_test)

    path_data_train_list = [f for f in datapath_train if dataname in f] + [f for f in datapath_random if dataname in f]

    for i, p in enumerate(poison_rate):
        X_train, y_train, _ = open_csv(path_data_train_list[i])
        clf = SVC(**svm_param)
        clf.fit(X_train, y_train)
        acc_train.append(clf.score(X_train, y_train))
        acc_test.append(clf.score(X_test, y_test))
        print(f'Accuracy on {p}% poison data train: {acc_train[i] * 100:.2f} test: {acc_test[i] * 100:.2f}')
    
    results = {
        'rate': poison_rate,
        'train': acc_train,
        'test': acc_test,
    }
    df = pd.DataFrame(results)
    df.to_csv(os.path.join(path_output, f'{dataname}_svm_random_score.csv'), index=False)
# Out:
# abalone_subset_std
# Accuracy on 0.00% poison data train: 81.44 test: 78.75
# Accuracy on 0.05% poison data train: 79.00 test: 78.00
# Accuracy on 0.10% poison data train: 74.12 test: 79.00
# Accuracy on 0.15% poison data train: 72.00 test: 77.50
# Accuracy on 0.20% poison data train: 69.56 test: 78.75
# Accuracy on 0.25% poison data train: 65.00 test: 77.75
# Accuracy on 0.30% poison data train: 63.12 test: 77.50
# Accuracy on 0.35% poison data train: 60.44 test: 74.00
# Accuracy on 0.40% poison data train: 57.56 test: 75.00
# australian_std
# Accuracy on 0.00% poison data train: 87.14 test: 90.58
# Accuracy on 0.05% poison data train: 82.61 test: 86.96
# Accuracy on 0.10% poison data train: 79.71 test: 86.23
# Accuracy on 0.15% poison data train: 76.99 test: 85.51
# Accuracy on 0.20% poison data train: 70.11 test: 86.23
# Accuracy on 0.25% poison data train: 67.75 test: 86.23
# Accuracy on 0.30% poison data train: 65.04 test: 87.68
# Accuracy on 0.35% poison data train: 59.42 test: 86.96
# Accuracy on 0.40% poison data train: 60.69 test: 78.99
# banknote_std
# Accuracy on 0.00% poison data train: 100.00 test: 100.00
# Accuracy on 0.05% poison data train: 95.08 test: 100.00
# Accuracy on 0.10% poison data train: 89.97 test: 99.27
# Accuracy on 0.15% poison data train: 84.78 test: 99.27
# Accuracy on 0.20% poison data train: 79.95 test: 99.27
# Accuracy on 0.25% poison data train: 75.02 test: 100.00
# Accuracy on 0.30% poison data train: 69.74 test: 99.27
# Accuracy on 0.35% poison data train: 65.18 test: 98.55
# Accuracy on 0.40% poison data train: 60.53 test: 97.82
# breastcancer_std
# Accuracy on 0.00% poison data train: 98.90 test: 99.12
# Accuracy on 0.05% poison data train: 95.38 test: 98.25
# Accuracy on 0.10% poison data train: 89.89 test: 95.61
# Accuracy on 0.15% poison data train: 84.84 test: 95.61
# Accuracy on 0.20% poison data train: 80.44 test: 94.74
# Accuracy on 0.25% poison data train: 79.56 test: 92.11
# Accuracy on 0.30% poison data train: 74.07 test: 87.72
# Accuracy on 0.35% poison data train: 69.45 test: 85.96
# Accuracy on 0.40% poison data train: 68.79 test: 76.32
# cmc_std
# Accuracy on 0.00% poison data train: 77.42 test: 77.29
# Accuracy on 0.05% poison data train: 74.70 test: 77.29
# Accuracy on 0.10% poison data train: 69.95 test: 77.29
# Accuracy on 0.15% poison data train: 68.93 test: 77.29
# Accuracy on 0.20% poison data train: 66.81 test: 77.29
# Accuracy on 0.25% poison data train: 62.65 test: 77.29
# Accuracy on 0.30% poison data train: 59.34 test: 77.29
# Accuracy on 0.35% poison data train: 58.40 test: 77.29
# Accuracy on 0.40% poison data train: 55.52 test: 77.29
# htru2_subset_std
# Accuracy on 0.00% poison data train: 94.69 test: 92.50
# Accuracy on 0.05% poison data train: 90.12 test: 93.50
# Accuracy on 0.10% poison data train: 85.25 test: 92.25
# Accuracy on 0.15% poison data train: 81.00 test: 92.00
# Accuracy on 0.20% poison data train: 77.62 test: 92.00
# Accuracy on 0.25% poison data train: 72.19 test: 92.00
# Accuracy on 0.30% poison data train: 68.19 test: 92.25
# Accuracy on 0.35% poison data train: 65.06 test: 92.00
# Accuracy on 0.40% poison data train: 62.25 test: 83.00
# phoneme_subset_std
# Accuracy on 0.00% poison data train: 87.81 test: 82.75
# Accuracy on 0.05% poison data train: 83.69 test: 82.75
# Accuracy on 0.10% poison data train: 79.62 test: 81.50
# Accuracy on 0.15% poison data train: 77.69 test: 80.25
# Accuracy on 0.20% poison data train: 72.38 test: 81.25
# Accuracy on 0.25% poison data train: 71.56 test: 80.25
# Accuracy on 0.30% poison data train: 65.38 test: 80.75
# Accuracy on 0.35% poison data train: 64.12 test: 76.75
# Accuracy on 0.40% poison data train: 62.38 test: 73.75
# ringnorm_subset_std
# Accuracy on 0.00% poison data train: 99.12 test: 96.00
# Accuracy on 0.05% poison data train: 94.00 test: 94.75
# Accuracy on 0.10% poison data train: 89.00 test: 92.75
# Accuracy on 0.15% poison data train: 85.12 test: 89.75
# Accuracy on 0.20% poison data train: 80.88 test: 89.25
# Accuracy on 0.25% poison data train: 77.25 test: 86.75
# Accuracy on 0.30% poison data train: 73.69 test: 83.00
# Accuracy on 0.35% poison data train: 71.56 test: 81.75
# Accuracy on 0.40% poison data train: 67.38 test: 73.50
# texture_subset_std
# Accuracy on 0.00% poison data train: 100.00 test: 100.00
# Accuracy on 0.05% poison data train: 98.25 test: 97.00
# Accuracy on 0.10% poison data train: 96.25 test: 92.50
# Accuracy on 0.15% poison data train: 94.00 test: 93.50
# Accuracy on 0.20% poison data train: 93.25 test: 83.50
# Accuracy on 0.25% poison data train: 91.38 test: 82.00
# Accuracy on 0.30% poison data train: 93.00 test: 74.00
# Accuracy on 0.35% poison data train: 89.88 test: 67.00
# Accuracy on 0.40% poison data train: 89.25 test: 66.00
# yeast_subset_std
# Accuracy on 0.00% poison data train: 70.97 test: 65.92
# Accuracy on 0.05% poison data train: 69.00 test: 62.01
# Accuracy on 0.10% poison data train: 69.57 test: 65.36
# Accuracy on 0.15% poison data train: 70.27 test: 59.78
# Accuracy on 0.20% poison data train: 67.04 test: 66.48
# Accuracy on 0.25% poison data train: 64.94 test: 63.69
# Accuracy on 0.30% poison data train: 64.38 test: 60.34
# Accuracy on 0.35% poison data train: 63.25 test: 59.78
# Accuracy on 0.40% poison data train: 63.25 test: 55.31

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

from label_flip_revised.simple_nn_model import SimpleModel
from label_flip_revised.torch_utils import evaluate, train_model

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
    print('Running on CPU!')

# %%
HIDDEN_LAYER = 128  # Number of hidden neurons in a hidden layer.
LR = 0.001  # Learning rate.
MAX_EPOCHS = 400  # Number of iteration for training.
BATCH_SIZE = 128

# %%
# Scores for Neural Networks
path_output = os.path.join(PATH_ROOT, 'results', 'real')
print(path_output)
create_dir(os.path.join(path_output, 'torch'))

for j, dataname in enumerate(datanames):
    print(dataname)
    acc_train = []
    acc_test = []

    path_clean_train = os.path.join(PATH_ROOT, 'data', 'output', 'train', dataname + '_clean_train.csv')
    path_clean_test = os.path.join(PATH_ROOT, 'data', 'output', 'test', dataname + '_clean_test.csv')
    X_train, y_train, _ = open_csv(path_clean_train)
    X_test, y_test, _ = open_csv(path_clean_test)
    n_features = X_train.shape[1]

    # Preprocessing
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    dataset_test = TensorDataset(torch.from_numpy(X_test).type(torch.float32),
                                 torch.from_numpy(y_test).type(torch.int64))
    dataloader_test = DataLoader(dataset_test, batch_size=BATCH_SIZE, shuffle=True)
    
    path_data_train_list = [f for f in datapath_train if dataname in f] + [f for f in datapath_flfa if dataname in f]

    for i, p in enumerate(poison_rate):
        _, y_train, _ = open_csv(path_data_train_list[i])
        dataset_train = TensorDataset(torch.from_numpy(X_train).type(torch.float32),
                                  torch.from_numpy(y_train).type(torch.int64))
        dataloader_train = DataLoader(dataset_train, batch_size=BATCH_SIZE, shuffle=True)

        model = SimpleModel(n_features, hidden_dim=HIDDEN_LAYER, output_dim=2).to(device)
        optimizer = torch.optim.SGD(model.parameters(), lr=LR, momentum=0.8)
        loss_fn = nn.CrossEntropyLoss()

        path_model = os.path.join(path_output, 'torch', dataname + f'_SimpleNN_flfa_{p}.torch')
        if os.path.exists(path_model):
            model.load_state_dict(torch.load(path_model, map_location=device))
        else:
            train_model(model, dataloader_train, optimizer, loss_fn, device, MAX_EPOCHS)
            torch.save(model.state_dict(), path_model)

        acc_poison, _ = evaluate(
            dataloader_train, model, loss_fn, device)
        acc_te, _ = evaluate(
            dataloader_test, model, loss_fn, device)

        acc_train.append(acc_poison)
        acc_test.append(acc_te)
        print(f'Accuracy on {p}% poison data train: {acc_train[i] * 100:.2f} test: {acc_test[i] * 100:.2f}')
    
    results = {
        'rate': poison_rate,
        'train': acc_train,
        'test': acc_test,
    }
    df = pd.DataFrame(results)
    df.to_csv(os.path.join(path_output, f'{dataname}_nn_flfa_score.csv'), index=False)
# Out:
# /home/lukec/workspace/label_flip_revised/results/real
# abalone_subset_std
# Accuracy on 0.00% poison data train: 75.06 test: 74.00
# Accuracy on 0.05% poison data train: 70.50 test: 73.50
# Accuracy on 0.10% poison data train: 72.19 test: 60.00
# Accuracy on 0.15% poison data train: 71.56 test: 55.25
# Accuracy on 0.20% poison data train: 77.44 test: 55.00
# Accuracy on 0.25% poison data train: 75.00 test: 50.00
# Accuracy on 0.30% poison data train: 80.00 test: 50.50
# Accuracy on 0.35% poison data train: 85.00 test: 50.00
# Accuracy on 0.40% poison data train: 90.00 test: 50.00
# australian_std
# Accuracy on 0.00% poison data train: 84.42 test: 82.61
# Accuracy on 0.05% poison data train: 72.64 test: 62.32
# Accuracy on 0.10% poison data train: 76.27 test: 77.54
# Accuracy on 0.15% poison data train: 70.47 test: 55.80
# Accuracy on 0.20% poison data train: 64.49 test: 44.20
# Accuracy on 0.25% poison data train: 80.43 test: 55.80
# Accuracy on 0.30% poison data train: 74.64 test: 44.20
# Accuracy on 0.35% poison data train: 90.40 test: 55.80
# Accuracy on 0.40% poison data train: 84.60 test: 44.20
# banknote_std
# Accuracy on 0.00% poison data train: 98.63 test: 98.55
# Accuracy on 0.05% poison data train: 99.18 test: 93.82
# Accuracy on 0.10% poison data train: 93.07 test: 83.27
# Accuracy on 0.15% poison data train: 90.15 test: 79.27
# Accuracy on 0.20% poison data train: 91.34 test: 75.27
# Accuracy on 0.25% poison data train: 92.80 test: 76.00
# Accuracy on 0.30% poison data train: 94.35 test: 65.82
# Accuracy on 0.35% poison data train: 97.54 test: 68.36
# Accuracy on 0.40% poison data train: 95.35 test: 54.55
# breastcancer_std
# Accuracy on 0.00% poison data train: 94.95 test: 93.86
# Accuracy on 0.05% poison data train: 89.23 test: 92.11
# Accuracy on 0.10% poison data train: 85.49 test: 92.98
# Accuracy on 0.15% poison data train: 77.58 test: 63.16
# Accuracy on 0.20% poison data train: 70.99 test: 66.67
# Accuracy on 0.25% poison data train: 87.69 test: 63.16
# Accuracy on 0.30% poison data train: 67.47 test: 36.84
# Accuracy on 0.35% poison data train: 97.58 test: 63.16
# Accuracy on 0.40% poison data train: 77.36 test: 36.84
# cmc_std
# Accuracy on 0.00% poison data train: 77.42 test: 77.29
# Accuracy on 0.05% poison data train: 72.58 test: 76.95
# Accuracy on 0.10% poison data train: 67.57 test: 77.29
# Accuracy on 0.15% poison data train: 78.10 test: 65.42
# Accuracy on 0.20% poison data train: 75.64 test: 56.27
# Accuracy on 0.25% poison data train: 83.02 test: 63.05
# Accuracy on 0.30% poison data train: 81.41 test: 48.14
# Accuracy on 0.35% poison data train: 92.19 test: 61.02
# Accuracy on 0.40% poison data train: 90.07 test: 45.76
# htru2_subset_std
# Accuracy on 0.00% poison data train: 92.00 test: 91.75
# Accuracy on 0.05% poison data train: 91.81 test: 88.25
# Accuracy on 0.10% poison data train: 85.69 test: 87.50
# Accuracy on 0.15% poison data train: 91.81 test: 80.25
# Accuracy on 0.20% poison data train: 84.38 test: 69.75
# Accuracy on 0.25% poison data train: 91.06 test: 68.50
# Accuracy on 0.30% poison data train: 88.50 test: 61.25
# Accuracy on 0.35% poison data train: 88.62 test: 52.75
# Accuracy on 0.40% poison data train: 90.00 test: 50.00
# phoneme_subset_std
# Accuracy on 0.00% poison data train: 77.88 test: 75.25
# Accuracy on 0.05% poison data train: 75.56 test: 66.00
# Accuracy on 0.10% poison data train: 74.88 test: 70.75
# Accuracy on 0.15% poison data train: 81.50 test: 62.50
# Accuracy on 0.20% poison data train: 75.06 test: 58.25
# Accuracy on 0.25% poison data train: 84.12 test: 55.25
# Accuracy on 0.30% poison data train: 81.44 test: 54.00
# Accuracy on 0.35% poison data train: 86.81 test: 49.50
# Accuracy on 0.40% poison data train: 91.19 test: 53.50
# ringnorm_subset_std
# Accuracy on 0.00% poison data train: 98.62 test: 96.50
# Accuracy on 0.05% poison data train: 91.62 test: 91.75
# Accuracy on 0.10% poison data train: 91.12 test: 81.25
# Accuracy on 0.15% poison data train: 88.31 test: 81.25
# Accuracy on 0.20% poison data train: 93.88 test: 71.25
# Accuracy on 0.25% poison data train: 87.50 test: 66.50
# Accuracy on 0.30% poison data train: 94.50 test: 63.50
# Accuracy on 0.35% poison data train: 89.38 test: 56.75
# Accuracy on 0.40% poison data train: 96.94 test: 55.50
# texture_subset_std
# Accuracy on 0.00% poison data train: 99.88 test: 99.50
# Accuracy on 0.05% poison data train: 97.50 test: 95.00
# Accuracy on 0.10% poison data train: 89.75 test: 99.00
# Accuracy on 0.15% poison data train: 81.12 test: 89.50
# Accuracy on 0.20% poison data train: 93.75 test: 74.00
# Accuracy on 0.25% poison data train: 94.12 test: 78.50
# Accuracy on 0.30% poison data train: 92.00 test: 61.50
# Accuracy on 0.35% poison data train: 96.25 test: 66.00
# Accuracy on 0.40% poison data train: 90.00 test: 50.00
# yeast_subset_std
# Accuracy on 0.00% poison data train: 67.04 test: 62.01
# Accuracy on 0.05% poison data train: 57.08 test: 51.40
# Accuracy on 0.10% poison data train: 62.97 test: 53.63
# Accuracy on 0.15% poison data train: 66.06 test: 52.51
# Accuracy on 0.20% poison data train: 72.23 test: 49.16
# Accuracy on 0.25% poison data train: 76.02 test: 51.96
# Accuracy on 0.30% poison data train: 79.38 test: 48.04
# Accuracy on 0.35% poison data train: 86.96 test: 51.96
# Accuracy on 0.40% poison data train: 88.08 test: 48.04

# %%
# NN with random noise
path_output = os.path.join(PATH_ROOT, 'results', 'real')
print(path_output)
create_dir(os.path.join(path_output, 'torch'))

for j, dataname in enumerate(datanames):
    print(dataname)
    acc_train = []
    acc_test = []

    path_clean_train = os.path.join(PATH_ROOT, 'data', 'output', 'train', dataname + '_clean_train.csv')
    path_clean_test = os.path.join(PATH_ROOT, 'data', 'output', 'test', dataname + '_clean_test.csv')
    X_train, y_train, _ = open_csv(path_clean_train)
    X_test, y_test, _ = open_csv(path_clean_test)
    n_features = X_train.shape[1]

    # Preprocessing
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    dataset_test = TensorDataset(torch.from_numpy(X_test).type(torch.float32), torch.from_numpy(y_test).type(torch.int64))
    dataloader_test = DataLoader(dataset_test, batch_size=BATCH_SIZE, shuffle=True)
    
    path_data_train_list = [f for f in datapath_train if dataname in f] + [f for f in datapath_random if dataname in f]

    for i, p in enumerate(poison_rate):
        _, y_train, _ = open_csv(path_data_train_list[i])
        dataset_train = TensorDataset(torch.from_numpy(X_train).type(torch.float32), torch.from_numpy(y_train).type(torch.int64))
        dataloader_train = DataLoader(dataset_train, batch_size=BATCH_SIZE, shuffle=True)

        model = SimpleModel(n_features, hidden_dim=HIDDEN_LAYER, output_dim=2).to(device)
        optimizer = torch.optim.SGD(model.parameters(), lr=LR, momentum=0.8)
        loss_fn = nn.CrossEntropyLoss()

        path_model = os.path.join(path_output, 'torch', dataname + f'_SimpleNN_random_{p}.torch')
        if os.path.exists(path_model):
            model.load_state_dict(torch.load(path_model, map_location=device))
        else:
            train_model(model, dataloader_train, optimizer, loss_fn, device, MAX_EPOCHS)
            torch.save(model.state_dict(), path_model)

        acc_poison, _ = evaluate(
            dataloader_train, model, loss_fn, device)
        acc_te, _ = evaluate(
            dataloader_test, model, loss_fn, device)

        acc_train.append(acc_poison)
        acc_test.append(acc_te)
        print(f'Accuracy on {p}% poison data train: {acc_train[i] * 100:.2f} test: {acc_test[i] * 100:.2f}')
    
    results = {
        'rate': poison_rate,
        'train': acc_train,
        'test': acc_test,
    }
    df = pd.DataFrame(results)
    df.to_csv(os.path.join(path_output, f'{dataname}_nn_random_score.csv'), index=False)
# Out:
# /home/lukec/workspace/label_flip_revised/results/real
# abalone_subset_std
# Accuracy on 0.00% poison data train: 75.25 test: 73.75
# Accuracy on 0.05% poison data train: 72.62 test: 73.25
# Accuracy on 0.10% poison data train: 70.25 test: 74.25
# Accuracy on 0.15% poison data train: 68.25 test: 73.75
# Accuracy on 0.20% poison data train: 64.81 test: 72.25
# Accuracy on 0.25% poison data train: 62.06 test: 72.25
# Accuracy on 0.30% poison data train: 59.19 test: 73.50
# Accuracy on 0.35% poison data train: 58.56 test: 72.50
# Accuracy on 0.40% poison data train: 55.00 test: 72.50
# australian_std
# Accuracy on 0.00% poison data train: 84.60 test: 87.68
# Accuracy on 0.05% poison data train: 81.88 test: 87.68
# Accuracy on 0.10% poison data train: 78.80 test: 85.51
# Accuracy on 0.15% poison data train: 73.37 test: 79.71
# Accuracy on 0.20% poison data train: 70.65 test: 78.26
# Accuracy on 0.25% poison data train: 68.66 test: 81.88
# Accuracy on 0.30% poison data train: 62.86 test: 76.09
# Accuracy on 0.35% poison data train: 46.74 test: 43.48
# Accuracy on 0.40% poison data train: 59.78 test: 81.88
# banknote_std
# Accuracy on 0.00% poison data train: 98.45 test: 98.55
# Accuracy on 0.05% poison data train: 92.98 test: 97.82
# Accuracy on 0.10% poison data train: 87.88 test: 97.09
# Accuracy on 0.15% poison data train: 81.31 test: 95.64
# Accuracy on 0.20% poison data train: 78.40 test: 96.00
# Accuracy on 0.25% poison data train: 73.47 test: 95.27
# Accuracy on 0.30% poison data train: 68.64 test: 97.09
# Accuracy on 0.35% poison data train: 63.90 test: 92.73
# Accuracy on 0.40% poison data train: 56.88 test: 75.64
# breastcancer_std
# Accuracy on 0.00% poison data train: 95.38 test: 94.74
# Accuracy on 0.05% poison data train: 91.87 test: 95.61
# Accuracy on 0.10% poison data train: 83.52 test: 94.74
# Accuracy on 0.15% poison data train: 81.10 test: 93.86
# Accuracy on 0.20% poison data train: 77.36 test: 92.11
# Accuracy on 0.25% poison data train: 67.25 test: 85.09
# Accuracy on 0.30% poison data train: 68.79 test: 89.47
# Accuracy on 0.35% poison data train: 63.96 test: 88.60
# Accuracy on 0.40% poison data train: 60.22 test: 87.72
# cmc_std
# Accuracy on 0.00% poison data train: 77.42 test: 77.29
# Accuracy on 0.05% poison data train: 74.70 test: 77.29
# Accuracy on 0.10% poison data train: 69.86 test: 77.29
# Accuracy on 0.15% poison data train: 68.93 test: 77.29
# Accuracy on 0.20% poison data train: 66.81 test: 77.29
# Accuracy on 0.25% poison data train: 62.65 test: 77.29
# Accuracy on 0.30% poison data train: 59.34 test: 77.29
# Accuracy on 0.35% poison data train: 58.40 test: 77.29
# Accuracy on 0.40% poison data train: 55.43 test: 77.29
# htru2_subset_std
# Accuracy on 0.00% poison data train: 91.75 test: 91.50
# Accuracy on 0.05% poison data train: 86.81 test: 90.50
# Accuracy on 0.10% poison data train: 81.81 test: 89.75
# Accuracy on 0.15% poison data train: 79.38 test: 91.25
# Accuracy on 0.20% poison data train: 73.69 test: 89.00
# Accuracy on 0.25% poison data train: 69.44 test: 90.75
# Accuracy on 0.30% poison data train: 65.31 test: 88.25
# Accuracy on 0.35% poison data train: 62.31 test: 90.25
# Accuracy on 0.40% poison data train: 58.81 test: 87.50
# phoneme_subset_std
# Accuracy on 0.00% poison data train: 76.25 test: 74.75
# Accuracy on 0.05% poison data train: 74.75 test: 74.75
# Accuracy on 0.10% poison data train: 71.06 test: 73.75
# Accuracy on 0.15% poison data train: 69.81 test: 75.50
# Accuracy on 0.20% poison data train: 66.56 test: 75.00
# Accuracy on 0.25% poison data train: 65.00 test: 76.25
# Accuracy on 0.30% poison data train: 61.25 test: 76.25
# Accuracy on 0.35% poison data train: 60.06 test: 74.50
# Accuracy on 0.40% poison data train: 58.13 test: 75.00
# ringnorm_subset_std
# Accuracy on 0.00% poison data train: 98.75 test: 94.50
# Accuracy on 0.05% poison data train: 92.00 test: 95.25
# Accuracy on 0.10% poison data train: 84.94 test: 92.50
# Accuracy on 0.15% poison data train: 80.12 test: 91.00
# Accuracy on 0.20% poison data train: 75.56 test: 91.75
# Accuracy on 0.25% poison data train: 71.75 test: 90.00
# Accuracy on 0.30% poison data train: 68.62 test: 91.50
# Accuracy on 0.35% poison data train: 63.81 test: 89.25
# Accuracy on 0.40% poison data train: 59.75 test: 77.50
# texture_subset_std
# Accuracy on 0.00% poison data train: 99.88 test: 100.00
# Accuracy on 0.05% poison data train: 94.50 test: 99.00
# Accuracy on 0.10% poison data train: 89.50 test: 99.00
# Accuracy on 0.15% poison data train: 84.00 test: 99.00
# Accuracy on 0.20% poison data train: 78.38 test: 98.00
# Accuracy on 0.25% poison data train: 72.88 test: 97.50
# Accuracy on 0.30% poison data train: 68.62 test: 97.00
# Accuracy on 0.35% poison data train: 62.25 test: 94.50
# Accuracy on 0.40% poison data train: 60.25 test: 97.50
# yeast_subset_std
# Accuracy on 0.00% poison data train: 65.36 test: 64.25
# Accuracy on 0.05% poison data train: 63.11 test: 61.45
# Accuracy on 0.10% poison data train: 63.25 test: 60.89
# Accuracy on 0.15% poison data train: 61.57 test: 61.45
# Accuracy on 0.20% poison data train: 60.31 test: 61.45
# Accuracy on 0.25% poison data train: 51.75 test: 53.63
# Accuracy on 0.30% poison data train: 56.94 test: 62.57
# Accuracy on 0.35% poison data train: 56.10 test: 50.84
# Accuracy on 0.40% poison data train: 55.40 test: 53.63
